# %%
import pandas as pd

df = pd.read_csv("heights.csv")
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
maxh = df['height'].quantile(0.95)
minh = df['height'].quantile(0.05)

# %%
df = df[(df['height'] > minh) & (df['height']< maxh)]

# %%
df1 = pd.read_csv("bhp.csv")

df1.shape
# Out:
# (13200, 7)

# %%
df1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
minh,maxh = df1.price_per_sqft.quantile([0.05,0.95])

# %%
df1= df1[(df1['price_per_sqft'] > minh) & ( df1['price_per_sqft'] < maxh)]

df1.shape
# Out:
# (11880, 7)

# %%
sn = pd.read_csv("AB_NYC_2019.csv")
sn
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
sn.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
min1,max1 = sn.price.quantile([0.01,0.95])
min2,max2 = sn.minimum_nights.quantile([0.05,0.95])
min3,max3 = sn.availability_365.quantile([0.05,0.95])
min4,max4 = sn.number_of_reviews.quantile([0.05,0.95])
max5 = sn.reviews_per_month.quantile(0.95)

# %%
sn = sn[(sn.price > min1) & (sn.price < max1)]
sn = sn[(sn.minimum_nights > min2) & (sn.minimum_nights < max2)]
sn = sn[(sn.number_of_reviews > min4) & (sn.number_of_reviews < max4)]
sn = sn[(sn.availability_365 > min3) & (sn.availability_365 < max3)]

sn = sn[(sn.availability_365 < max5)]

# %%
sn.shape
# Out:
# (789, 16)

# %%
sn
# Out:
#              id                                              name    host_id  \
# 143       32363                Fully Furnished Basement Apartment     140025
# 183       45940                      Bright Spacious Luxury Condo     204724
# 221       57618                Great new apt, close to everything     274557
# 413      139624               Spacious,Sunny, private one bedroom     680818
# 638      241159          Clinton Hill 1 Bed Bright Loft Apartment    1264655
# ...         ...                                               ...        ...
# 47403  35716058                   Lux 23rd Fl. Wall St. Apartment    7169907
# 47490  35768121                                Murray Hill studio    2448443
# 47564  35804219          Cozy room available in Brooklyn for July   35616021
# 47944  35999182  Comfortable room in Brooklyn 30 min to Manhattan  270823235
# 47948  35999735             Bedroom in Astoria 20min to Manhattan  259683021
#
# ...

# %%
min1,max1 = sn.price.quantile([0.01,0.95])
sn = sn[(sn.price > min1) & (sn.price < max1)]
sn.shape
# Out:
# (45785, 16)

# %%
dfo = pd.read_csv("weight-height.csv")

dfo
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.hist(dfo.Height,bins = 30)
# Out:
# (array([  3.,   6.,  14.,  40.,  59., 119., 186., 321., 419., 556., 632.,
#         718., 720., 738., 738., 753., 739., 675., 640., 513., 459., 387.,
#         219., 159.,  95.,  44.,  24.,  16.,   4.,   4.]),
#  array([54.26313333, 55.08765363, 55.91217393, 56.73669423, 57.56121453,
#         58.38573483, 59.21025513, 60.03477543, 60.85929573, 61.68381603,
#         62.50833633, 63.33285663, 64.15737693, 64.98189723, 65.80641754,
#         66.63093784, 67.45545814, 68.27997844, 69.10449874, 69.92901904,
#         70.75353934, 71.57805964, 72.40257994, 73.22710024, 74.05162054,
#         74.87614084, 75.70066114, 76.52518144, 77.34970174, 78.17422205,
#         78.99874235]),
#  <BarContainer object of 30 artists>)
