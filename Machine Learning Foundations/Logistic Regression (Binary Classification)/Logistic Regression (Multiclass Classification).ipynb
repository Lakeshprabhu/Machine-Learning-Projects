# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

# %%
d = load_digits()

dir(d)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
plt.gray()

# %%
for j in range(0,10):
    plt.matshow(d['images'][j])

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(d.data,d.target,test_size = 0.2)

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\thang\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
plt.matshow(d['images'][9])

# %%
taco = model.predict(X_test)

# %%
d.target[10]
# Out:
# 0

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,taco)

# %%
import seaborn as sn

sn.heatmap(cm,annot=True)
# Out:
# <Axes: >
