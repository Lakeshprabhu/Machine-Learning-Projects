# %%
import pandas as pd

df = pd.read_csv("Melbourne_housing_FULL.csv")

df.shape
# Out:
# (34857, 21)

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
columd = ['Bedroom2','Bathroom',"Propertycount","Car"]

df[columd] = df[columd].fillna(0)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df['Distance'] = df['Distance'].fillna(0)

# %%
df['Landsize'] = df['Landsize'].fillna(df['Landsize'].mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df['BuildingArea'].mean())

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea         0
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        0
# dtype: int64

# %%
df = df.drop(['Lattitude','Longtitude','Date','Postcode','YearBuilt','CouncilArea'],axis='columns')

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            7609
# Method              0
# SellerG             0
# Distance            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Regionname          3
# Propertycount       0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.shape
# Out:
# (27244, 15)

# %%
dataset = pd.get_dummies(df,drop_first=True)

# %%
dataset
# Out:
#        Rooms      Price  Distance  Bedroom2  Bathroom  Car    Landsize  \
# 1          2  1480000.0       2.5       2.0       1.0  1.0  202.000000
# 2          2  1035000.0       2.5       2.0       1.0  0.0  156.000000
# 4          3  1465000.0       2.5       3.0       2.0  0.0  134.000000
# 5          3   850000.0       2.5       3.0       2.0  1.0   94.000000
# 6          4  1600000.0       2.5       3.0       1.0  2.0  120.000000
# ...      ...        ...       ...       ...       ...  ...         ...
# 34852      4  1480000.0       6.3       4.0       1.0  3.0  593.000000
# 34853      2   888000.0       6.3       2.0       2.0  1.0   98.000000
# 34854      2   705000.0       6.3       2.0       1.0  2.0  220.000000
# 34855      3  1140000.0       6.3       0.0       0.0  0.0  593.607177
# 34856      2  1020000.0       6.3       2.0       1.0  0.0  250.000000
#
#        BuildingArea  Propertycount  Suburb_Aberfeldie  ...  SellerG_iProperty  \
# ...

# %%
X = dataset.drop('Price',axis='columns')

X
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# 1          2       2.5       2.0       1.0  1.0  202.000000    160.251616
# 2          2       2.5       2.0       1.0  0.0  156.000000     79.000000
# 4          3       2.5       3.0       2.0  0.0  134.000000    150.000000
# 5          3       2.5       3.0       2.0  1.0   94.000000    160.251616
# 6          4       2.5       3.0       1.0  2.0  120.000000    142.000000
# ...      ...       ...       ...       ...  ...         ...           ...
# 34852      4       6.3       4.0       1.0  3.0  593.000000    160.251616
# 34853      2       6.3       2.0       2.0  1.0   98.000000    104.000000
# 34854      2       6.3       2.0       1.0  2.0  220.000000    120.000000
# 34855      3       6.3       0.0       0.0  0.0  593.607177    160.251616
# 34856      2       6.3       2.0       1.0  0.0  250.000000    103.000000
#
#        Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y = dataset.Price
y
# Out:
# 1        1480000.0
# 2        1035000.0
# 4        1465000.0
# 5         850000.0
# 6        1600000.0
#            ...
# 34852    1480000.0
# 34853     888000.0
# 34854     705000.0
# 34855    1140000.0
# 34856    1020000.0
# Name: Price, Length: 27244, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2 ,random_state=2)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge

mod = LinearRegression()

# %%
mod.fit(X_train,y_train)
mod.score(X_train,y_train)

# %%
ls = Lasso(alpha=50,max_iter = 100, tol = 0.1)

rd = Ridge(alpha = 50,max_iter = 100, tol = 0.1 )
